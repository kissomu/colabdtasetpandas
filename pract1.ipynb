# %% [markdown]
# <a href="https://colab.research.google.com/github/kissomu/colabdtasetpandas/blob/main/pract1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from pylab import randn
X = randn(222)
Y = randn(222)
plt.scatter(X,Y, color='g')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
import matplotlib.pyplot as plt

languages = 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'
popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]



 

plt.pie(popuratity, labels=languages, )

plt.title("PopularitY of Programming Language\n")
plt.show()

# %%
import matplotlib.pyplot as plt

languages = 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'
popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.scatter(x=popuratity, y=languages )

plt.title("PopularitY of Programming Language\n")
plt.show()

# %%
import matplotlib.pyplot as plt 
import random


x = [random.randrange(1,50,1) for i in range (20)]
y = [random.randrange(1,50,1) for i in range (20)]
plt.scatter(x, y, s=200, facecolors='none', edgecolors='b')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
import matplotlib.pyplot as plt 
import random
x = [random.randrange(1,50,1) for i in range (20)]
y = [random.randrange(1,50,1) for i in range (20)]
plt.scatter(x, y, s=1200, facecolors='r', edgecolors='w')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x = np.random.randn(50) 
y = np.random.randn(50)
plt.scatter(x, y, s=800, facecolors='r', edgecolors='b')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
sns.scatterplot(data=tips, x="total_bill", y="tip", size="size",color="r")

# %%
import matplotlib.pyplot as plt
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, popularity, color=['red', 'black', 'green', 'blue', 'yellow', 'cyan'])

plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")


plt.show()

# %%
import matplotlib.pyplot as plt
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.bar(x, popularity, color=['red', 'black', 'green', 'blue', 'yellow', 'cyan'])

plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("PopularitY of Programming Language\n")
# Out:
# Text(0.5, 1.0, 'PopularitY of Programming Language\n')
