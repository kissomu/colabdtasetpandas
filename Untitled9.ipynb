# %% [markdown]
# <a href="https://colab.research.google.com/github/kissomu/colabdtasetpandas/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('1. Weather Data.csv')

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Dew Point Temp_C'].unique()
# Out:
# array([ -3.9,  -3.7,  -3.4,  -3.2,  -3.3,  -3.1,  -3.6,  -2.3,  -2.1,
#         -2. ,  -1.7,  -1.1,  -0.4,  -0.2,   0. ,   1. ,   1.3,   1.7,
#          1.9,   2. ,   1.5,  -0.9,  -1.5,  -2.6,  -2.9,  -4.1,  -3.5,
#         -6.2,  -6.5,  -6.8,  -7. ,  -8.7,  -9.5, -11.4, -12.1, -13.4,
#        -12.8, -14.7, -14.1, -16. , -17.2, -15.8, -18.7, -20.1, -19.1,
#        -19.3, -19.5, -21.3, -21.9, -22.2, -22.6, -22.4, -22.9, -23.2,
#        -23.8, -24.8, -25.4, -24.6, -24.2, -24.1, -24. , -22.5, -20.6,
#        -21.1, -21.7, -19. , -16.3, -15.5, -13.2, -12.6, -12.7, -11.6,
#        -11.7, -10.2,  -8.3,  -7.7, -10.7,  -9.7,  -9.1, -10.1, -10. ,
#         -9.6, -12. , -14.4, -15.4, -15.7, -14.8, -16.8, -17.3, -16.5,
#        -16.1, -16.2, -16.7, -15.6, -14.3, -13.6, -13. , -12.5, -12.2,
#        -11.1, -10.8, -10.5,  -9. ,  -8. ,  -7.8,  -7.2,  -6.9,  -6.1,
#         -5.9,  -5.4,  -5.3,  -5. ,  -3. ,  -4.6,  -9.2, -10.3, -11.9,
# ...

# %%
data['Dew Point Temp_C'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0      -3.9
# 1      -3.7
# 2      -3.4
# 3      -3.2
# 4      -3.3
#        ...
# 8779   -2.7
# 8780   -2.4
# 8781   -1.5
# 8782   -1.8
# 8783   -2.1
# Name: Dew Point Temp_C, Length: 8784, dtype: float64>

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  ...  Visibility_km  Press_kPa  Weather
# 0  1/1/2012 0:00    -1.8              -3.9  ...            8.0     101.24      Fog
# 1  1/1/2012 1:00    -1.8              -3.7  ...            8.0     101.24      Fog
#
# [2 rows x 8 columns]

# %%
data[ data.Weather == 'clear']
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather]
# Index: []

# %% [markdown]
# find all unique 'wind speed' value in the data

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# Q2. find the number of times weather is exectly clear

# %%
data.Weather.value_counts() #value count method
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#filtering method
data[data.Weather== 'clear']
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather]
# Index: []

# %% [markdown]
# Q2-find the number of times when the wind speed was exectly 4km/h

# %%
data[data['Wind Speed_km/h'] == 4]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa       Weather
# 0        1/1/2012 0:00    -1.8  ...     101.24           Fog
# 1        1/1/2012 1:00    -1.8  ...     101.24           Fog
# 96       1/5/2012 0:00    -8.8  ...     100.32          Snow
# 101      1/5/2012 5:00    -7.0  ...     100.19          Snow
# 146      1/7/2012 2:00    -8.1  ...     100.15        Cloudy
# ...                ...     ...  ...        ...           ...
# 8768   12/31/2012 8:00    -8.6  ...     101.14  Snow Showers
# 8769   12/31/2012 9:00    -8.1  ...     101.09          Snow
# 8770  12/31/2012 10:00    -7.4  ...     101.05      Snow,Fog
# 8772  12/31/2012 12:00    -5.8  ...     100.78          Snow
# 8773  12/31/2012 13:00    -4.6  ...     100.63          Snow
#
# [474 rows x 8 columns]

# %% [markdown]
# Q4-find out all the nullvalue in data

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
#for notnull
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# Q5 Rename the clumn name 'weather' of the data frame to weather condition

# %%
data.rename(columns ={'Weather':'Weather condition'}, inplace=True)

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  ...  Press_kPa  Weather condition
# 0  1/1/2012 0:00    -1.8  ...     101.24                Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                Fog
#
# [2 rows x 8 columns]

# %% [markdown]
# Q6- what is the mean of visibility?

# %%
data.Visibility_km.mean()
# Out:
# 27.66444672131151

# %% [markdown]
# Q7-what is the stnadrad deviation of PRESSURE  in this data

# %%
data.Press_kPa.std()
# Out:
# 0.8440047459486474

# %% [markdown]
# Q8- what is the veriance of relative humidity in this data

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# q9-find all instance when snow was recorded

# %%
data['Weather condition'].value_counts() #method1
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data[data['Weather condition'].str.contains('snow')].head(50)
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather condition]
# Index: []

# %% [markdown]
# Q10- find all instance when wind speed above 24 and visibility is 25

# %%
data[(data['Wind Speed_km/h']>24) & (data['Visibility_km']==24)]
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather condition]
# Index: []

# %% [markdown]
# Q11- what is the mean,max and minimum value of each column against each 'weather condition'

# %%
data.groupby('Weather condition').mean()
# Out:
#                                             Temp_C  ...   Press_kPa
# Weather condition                                   ...
# Clear                                     6.825716  ...  101.587443
# Cloudy                                    7.970544  ...  100.911441
# Drizzle                                   7.353659  ...  100.435366
# Drizzle,Fog                               8.067500  ...  100.786625
# Drizzle,Ice Pellets,Fog                   0.400000  ...  100.790000
# Drizzle,Snow                              1.050000  ...  100.890000
# Drizzle,Snow,Fog                          0.693333  ...   99.281333
# Fog                                       4.303333  ...  101.184067
# Freezing Drizzle                         -5.657143  ...  100.202857
# Freezing Drizzle,Fog                     -2.533333  ...  100.441667
# Freezing Drizzle,Haze                    -5.433333  ...  100.316667
# Freezing Drizzle,Snow                    -5.109091  ...  100.520909
# ...

# %%
data.groupby('Weather condition').min()
# Out:
#                                                 Date/Time  ...  Press_kPa
# Weather condition                                          ...
# Clear                                      1/11/2012 1:00  ...      99.52
# Cloudy                                     1/1/2012 17:00  ...      98.39
# Drizzle                                   1/23/2012 21:00  ...      97.84
# Drizzle,Fog                               1/23/2012 20:00  ...      98.65
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00  ...     100.79
# Drizzle,Snow                             12/17/2012 15:00  ...     100.63
# Drizzle,Snow,Fog                         12/18/2012 21:00  ...      97.79
# Fog                                         1/1/2012 0:00  ...      98.31
# Freezing Drizzle                          1/13/2012 10:00  ...      98.44
# Freezing Drizzle,Fog                        1/1/2012 2:00  ...      98.74
# Freezing Drizzle,Haze                      2/1/2012 11:00  ...     100.28
# ...

# %%
data.groupby('Weather condition').max()
# Out:
#                                                 Date/Time  ...  Press_kPa
# Weather condition                                          ...
# Clear                                       9/9/2012 5:00  ...     103.63
# Cloudy                                     9/9/2012 23:00  ...     103.65
# Drizzle                                    9/30/2012 3:00  ...     101.56
# Drizzle,Fog                                9/30/2012 2:00  ...     102.07
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00  ...     100.79
# Drizzle,Snow                             12/19/2012 18:00  ...     101.15
# Drizzle,Snow,Fog                          12/22/2012 3:00  ...     100.15
# Fog                                        9/22/2012 0:00  ...     103.04
# Freezing Drizzle                            2/1/2012 5:00  ...     101.02
# Freezing Drizzle,Fog                      12/10/2012 5:00  ...     101.27
# Freezing Drizzle,Haze                      2/1/2012 13:00  ...     100.36
# ...

# %% [markdown]
# Q12 SHOW all the records where wheather condition is fog

# %%
data[data['Weather condition']=='fog']
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather condition]
# Index: []

# %% [markdown]
# Q13- FInd all the instance when 'wheather is clear or visibility is above 40

# %%
data[(data['Weather condition']=='clear') | (data['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  ...  Press_kPa  Weather condition
# 106     1/5/2012 10:00    -6.0  ...     100.45       Mainly Clear
# 107     1/5/2012 11:00    -5.6  ...     100.41       Mainly Clear
# 108     1/5/2012 12:00    -4.7  ...     100.38       Mainly Clear
# 109     1/5/2012 13:00    -4.4  ...     100.40       Mainly Clear
# 110     1/5/2012 14:00    -5.1  ...     100.46       Mainly Clear
# ...                ...     ...  ...        ...                ...
# 8748  12/30/2012 12:00   -12.2  ...     100.91      Mostly Cloudy
# 8749  12/30/2012 13:00   -12.4  ...     100.92      Mostly Cloudy
# 8750  12/30/2012 14:00   -11.8  ...     100.96       Mainly Clear
# 8751  12/30/2012 15:00   -11.3  ...     101.05       Mainly Clear
# 8752  12/30/2012 16:00   -11.4  ...     101.15       Mainly Clear
#
# [2014 rows x 8 columns]

# %% [markdown]
# Q14 Find all the instanc when 1 wheather is clear and relative humidy is graten then 50 (2)-visibility is above40

# %%
data[(data['Weather condition']== 'clear') & (data['Rel Hum_%']>50) | (data['Visibility_km']>50)]
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather condition]
# Index: []
