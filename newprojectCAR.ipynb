# %% [markdown]
# <a href="https://colab.research.google.com/github/kissomu/colabdtasetpandas/blob/main/newprojectCAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('2. Cars Data1.csv')

# %%
df.head(2)
# Out:
#     Make           Model   Type Origin  ... MPG_Highway  Weight Wheelbase  Length
# 0  Acura             MDX    SUV   Asia  ...        23.0  4451.0     106.0   189.0
# 1  Acura  RSX Type S 2dr  Sedan   Asia  ...        31.0  2778.0     101.0   172.0
#
# [2 rows x 15 columns]

# %% [markdown]
# # ***Q1 find the null value in data set, if there any null value find cylinder column then replace oit with mean value of that column***

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df['Cylinders'].fillna(df['Cylinders'].mean(),inplace = True)

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      0
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %% [markdown]
# # ***Q2 what is the different type of make in there in the dta set***

# %%
df['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Nissan           17
# Honda            17
# Volkswagen       15
# Chrysler         15
# Mitsubishi       13
# Dodge            13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Lexus            11
# Kia              11
# Pontiac          11
# Mazda            11
# Mercury           9
# Lincoln           9
# Buick             9
# Infiniti          8
# GMC               8
# Suzuki            8
# Cadillac          8
# Saturn            8
# Saab              7
# Acura             7
# Porsche           7
# Land Rover        3
# Jeep              3
# Oldsmobile        3
# Isuzu             2
# MINI              2
# Scion             2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# # ***Q3 show all the record where origin asia or europe.(filtring)***

# %%
df[df['Origin'].isin(['Asia', 'Europe'])].head(50)
# Out:
#       Make                                   Model  ... Wheelbase Length
# 0    Acura                                     MDX  ...     106.0  189.0
# 1    Acura                          RSX Type S 2dr  ...     101.0  172.0
# 2    Acura                                 TSX 4dr  ...     105.0  183.0
# 3    Acura                                  TL 4dr  ...     108.0  186.0
# 4    Acura                              3.5 RL 4dr  ...     115.0  197.0
# 5    Acura                 3.5 RL w/Navigation 4dr  ...     115.0  197.0
# 6    Acura                  NSX coupe 2dr manual S  ...     100.0  174.0
# 7     Audi                             A4 1.8T 4dr  ...     104.0  179.0
# 8     Audi                  A41.8T convertible 2dr  ...     105.0  180.0
# 9     Audi                              A4 3.0 4dr  ...     104.0  179.0
# 10    Audi               A4 3.0 Quattro 4dr manual  ...     104.0  179.0
# 11    Audi                 A4 3.0 Quattro 4dr auto  ...     104.0  179.0
# ...

# %% [markdown]
# # ***Q4 Remove all the records where (rows) where weight is above 4000***

# %%
df[~(df['Weight']>4000)]
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan  ...  3893.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [329 rows x 15 columns]

# %% [markdown]
# # ***Q4 Incraese  all the value of MPG_CITY cloumn by 3(applying function on a column)***

# %%
df['MPG_City'] = df['MPG_City'].apply(lambda x:x+3)

# %%
df
# Out:
#       Make                    Model   Type  ...  Weight Wheelbase Length
# 0    Acura                      MDX    SUV  ...  4451.0     106.0  189.0
# 1    Acura           RSX Type S 2dr  Sedan  ...  2778.0     101.0  172.0
# 2    Acura                  TSX 4dr  Sedan  ...  3230.0     105.0  183.0
# 3    Acura                   TL 4dr  Sedan  ...  3575.0     108.0  186.0
# 4    Acura               3.5 RL 4dr  Sedan  ...  3880.0     115.0  197.0
# ..     ...                      ...    ...  ...     ...       ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 428  Volvo  C70 HPT convertible 2dr  Sedan  ...  3450.0     105.0  186.0
# 429  Volvo               S80 T6 4dr  Sedan  ...  3653.0     110.0  190.0
# 430  Volvo                      V40  Wagon  ...  2822.0     101.0  180.0
# 431  Volvo                     XC70  Wagon  ...  3823.0     109.0  186.0
#
# [432 rows x 15 columns]

# %% [markdown]
# # ***                             second project done***
